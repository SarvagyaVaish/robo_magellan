# %%
import math
from tabulate import tabulate
from pint import UnitRegistry


units = UnitRegistry()
print(f"Using {units.default_system} units")

# %%
# # Physical constants
# ROBOT_NUM_POWERED_WHEELS = 4
# ROBOT_MASS = 20 * units.pounds
# ROBOT_WHEEL_RADIUS = 3 * units.inches
# G = 9.81 * units.meter / units.second**2

# # Dynamics constants
# # Nominal
# NOMINAL_SPEED = 2 * units.meter / units.second
# NOMINAL_ACCEL = 2 * units.meter / units.second**2
# # Incline
# INCLINE_GRADE = 20 * units.degrees  # This is what 30 deg looks like: https://www.youtube.com/watch?v=tEEgINoP2-o
# INCLINE_SPEED = 1 * units.meter / units.second
# INCLINE_ACCEL = 1 * units.meter / units.second**2

# #   Common CRF (Coefficient of Rolling Friction) values
# #     0.02		car tires on tar or asphalt
# #     0.06		car tire on solid sand, gravel loose worn, soil medium hard
# #     0.35    car tire on field
# #     0.40		car tire on loose sand
# FRICTION_COEFF = 0.35

# EFFICIENCY = 0.65

# # Convert to base units
# ROBOT_MASS.ito_base_units()
# ROBOT_WHEEL_RADIUS.ito_base_units()
# NOMINAL_SPEED.ito_base_units()
# INCLINE_SPEED.ito_base_units()

# print(
#     f"""
# Weight
#     {ROBOT_MASS.to("kg"):.3f}
#     {ROBOT_MASS.to("lbs"):.3f}

# Wheel (radius / diameter)
#     {ROBOT_WHEEL_RADIUS.to("in"):.3f} / {2 * ROBOT_WHEEL_RADIUS.to("in"):.3f}
#     {ROBOT_WHEEL_RADIUS.to("cm"):.3f} / {2 * ROBOT_WHEEL_RADIUS.to("cm"):.3f}
#     {ROBOT_WHEEL_RADIUS.to("m"):.3f} / {2 * ROBOT_WHEEL_RADIUS.to("m"):.3f}

# Number of powered wheels
#     {ROBOT_NUM_POWERED_WHEELS}
# """
# )

# %% [markdown]
# ### While on flat ground

# %%
# # Force is needed to overcome friction and accelerate the robot
# #   Force = Force_accel + Force_friction
# #         = m * a       + crf * m * g
# #   Units: kg * m / s2

# force_acceleration = ROBOT_MASS * NOMINAL_ACCEL
# force_acceleration.ito("N")
# force_friction = FRICTION_COEFF * ROBOT_MASS * G
# force_friction.ito("N")

# print(f"Force for acceleration:\n  {force_acceleration:.3f}")
# print(f"Force for friction:\n  {force_friction:.3f}")
# print("")

# # Torque is the force needed to rotate an object
# #   Torue = Force * Radius
# #   Units: N m

# torque_for_accel = force_acceleration * ROBOT_WHEEL_RADIUS
# torque_for_friction = force_friction * ROBOT_WHEEL_RADIUS

# torque_for_accel_per_wheel = torque_for_accel / ROBOT_NUM_POWERED_WHEELS
# torque_for_accel_per_wheel.ito("N m")
# torque_for_friction_per_wheel = torque_for_friction / ROBOT_NUM_POWERED_WHEELS
# torque_for_friction_per_wheel.ito("N m")
# torque_total_per_wheel = torque_for_accel_per_wheel + torque_for_friction_per_wheel
# desired_motor_torque_per_wheel = torque_total_per_wheel / EFFICIENCY

# print(f"Torque for acceleration per wheel:\n  {torque_for_accel_per_wheel:.3f}")
# print(f"Torque for friction per wheel:\n  {torque_for_friction_per_wheel:.3f}")
# print("")


# # RPM
# #   RPM = speed / circumference
# rpm = NOMINAL_SPEED.to("meters / minute") / (2 * math.pi * ROBOT_WHEEL_RADIUS)

# # Summary
# print(f"For flat ground")
# print(f"---------------")
# print(f"Torque per wheel (x{ROBOT_NUM_POWERED_WHEELS}):\n  {torque_total_per_wheel:.3f}")
# print(
#     f"""Desired motor torque per wheel (x{ROBOT_NUM_POWERED_WHEELS}):
#   {desired_motor_torque_per_wheel:.3f}
#   {desired_motor_torque_per_wheel.magnitude * 8.8507457916:.3f} in-lb
#   {desired_motor_torque_per_wheel.magnitude * 141.6119326656:.3f} oz-in
#   {desired_motor_torque_per_wheel.magnitude * 10.1971621298:.3f} kg-cm
# """
# )

# print(f"Speed:\n  {NOMINAL_SPEED:.3f}")
# print(f"Accel:\n  {NOMINAL_ACCEL:.3f}")
# print(f"RPM:\n  {rpm:.3f}")

# %% [markdown]
# ### While on an incline

# %%
# # Force is needed to overcome friction and accelerate the robot
# #   Force = Force_accel          +  Force_friction
# #         = m * (a + g sin(th))  +  crf * m * g * cos(th)
# #   Units: kg * m / s2

# force_acceleration = ROBOT_MASS * (INCLINE_ACCEL + G * math.sin(INCLINE_GRADE))
# force_acceleration.ito("N")
# force_friction = FRICTION_COEFF * ROBOT_MASS * G * math.cos(INCLINE_GRADE)
# force_friction.ito("N")

# print(f"Force for acceleration:\n  {force_acceleration:.3f}")
# print(f"Force for friction:\n  {force_friction:.3f}")
# print("")

# # Torque is the force needed to rotate an object
# #   Torue = Force * Radius
# #   Units: N m

# torque_for_accel = force_acceleration * ROBOT_WHEEL_RADIUS
# torque_for_friction = force_friction * ROBOT_WHEEL_RADIUS

# torque_for_accel_per_wheel = torque_for_accel / ROBOT_NUM_POWERED_WHEELS
# torque_for_accel_per_wheel.ito("N m")
# torque_for_friction_per_wheel = torque_for_friction / ROBOT_NUM_POWERED_WHEELS
# torque_for_friction_per_wheel.ito("N m")
# torque_total_per_wheel = torque_for_accel_per_wheel + torque_for_friction_per_wheel
# desired_motor_torque_per_wheel = torque_total_per_wheel / EFFICIENCY

# print(f"Torque for acceleration per wheel:\n  {torque_for_accel_per_wheel:.3f}")
# print(f"Torque for friction per wheel:\n  {torque_for_friction_per_wheel:.3f}")
# print("")


# # RPM
# #   RPM = speed / circumference
# rpm = INCLINE_SPEED.to("meters / minute") / (2 * math.pi * ROBOT_WHEEL_RADIUS)

# # Summary
# print(f"For nominal case")
# print(f"----------------")
# print(f"Incline angle:\n  {INCLINE_GRADE:.3f}")
# print(f"Torque per wheel (x{ROBOT_NUM_POWERED_WHEELS}):\n  {torque_total_per_wheel:.3f}")
# print(
#     f"""Desired motor torque per wheel (x{ROBOT_NUM_POWERED_WHEELS}):
#   {desired_motor_torque_per_wheel:.3f}
#   {desired_motor_torque_per_wheel.to("kgf mm"):.3f}
#   {desired_motor_torque_per_wheel.to("kgf cm"):.3f}
#   {desired_motor_torque_per_wheel.to("lbf in"):.3f}
#   {desired_motor_torque_per_wheel.to("ozf in"):.3f}
# """
# )
# print(f"Speed:\n  {INCLINE_SPEED:.3f}")
# print(f"Accel:\n  {INCLINE_ACCEL:.3f}")
# print(f"RPM:\n  {rpm:.3f}")

# %%
def calculate_motor_requirements(
    robot_mass,
    robot_num_powered_wheels,
    robot_wheel_radius,
    speed,
    accel,
    incline_grade,
):

    # Force is needed to overcome friction and accelerate the robot
    #   Force = Force_accel          +  Force_friction
    #         = m * (a + g sin(th))  +  crf * m * g * cos(th)
    #   Units: kg * m / s2

    force_acceleration = robot_mass * (accel + G * math.sin(incline_grade))
    force_acceleration.ito("N")
    force_friction = FRICTION_COEFF * robot_mass * G * math.cos(incline_grade)
    force_friction.ito("N")

    # Torque is the force needed to rotate an object
    #   Torue = Force * Radius
    #   Units: N m

    torque_for_accel = force_acceleration * robot_wheel_radius
    torque_for_accel.ito("N m")
    torque_for_friction = force_friction * robot_wheel_radius
    torque_for_friction.ito("N m")

    torque_total_per_wheel = (torque_for_accel + torque_for_friction) / robot_num_powered_wheels
    desired_motor_torque = torque_total_per_wheel / EFFICIENCY

    # RPM
    #   RPM = speed / circumference
    rpm = None
    if speed is not None:
        rpm = speed / robot_wheel_radius
        rpm.ito("rpm")

    return desired_motor_torque, rpm

# %%
G = 9.81 * units.meter / units.second**2
EFFICIENCY = 0.8

#   Common CRF (Coefficient of Rolling Friction) values
#     0.02		car tires on tar or asphalt
#     0.06		car tire on solid sand, gravel loose worn, soil medium hard
#     0.35    car tire on field
#     0.40		car tire on loose sand
FRICTION_COEFF = 0.1


robot_num_powered_wheels = 4
robot_mass = 10 * units.pounds
robot_wheel_radius = 3.0 * units.inches

speed = 0.5 * units.mps
accel = 0.5 * units.meter / units.second**2
incline_grade = 20 * units.degrees

torque, rpm = calculate_motor_requirements(
    robot_mass, robot_num_powered_wheels, robot_wheel_radius, speed, accel, incline_grade
)

print(
    f"""Desired motor torque (x{robot_num_powered_wheels}):
  {torque:.3f}
    {torque * 4:.3f} (stall)
  {torque.to("kgf mm"):.3f}
  {torque.to("kgf cm"):.3f}
  {torque.to("lbf in"):.3f}
  {torque.to("ozf in"):.3f}
RPM:
  {rpm:.3f}
"""
)
# Out:
# Desired motor torque (x4):
#   0.516 meter * newton
#     2.064 meter * newton (stall)
#   52.615 force_kilogram * millimeter
#   5.262 centimeter * force_kilogram
#   4.567 force_pound * inch
#   73.069 force_ounce * inch
# RPM:
#   62.659 revolutions_per_minute

# %%
G = 9.81 * units.meter / units.second**2
EFFICIENCY = 0.8

#   Common CRF (Coefficient of Rolling Friction) values
#     0.02		car tires on tar or asphalt
#     0.06		car tire on solid sand, gravel loose worn, soil medium hard
#     0.35    car tire on field
#     0.40		car tire on loose sand
FRICTION_COEFF = 0.1

robot_num_powered_wheels = 4
robot_mass = 10 * units.pounds
robot_wheel_radius = 3.0 * units.inches

headers = ["State", "RPM", "Torque (Nm)", "Torque (kg mm)", "Torque (kg cm)"]
table = []


#
# Max speed on incline
#
speed = 2.0 * units.mps
accel = 0.0 * units.meter / units.second**2
incline_grade = 0 * units.degrees

torque, rpm = calculate_motor_requirements(
    robot_mass, robot_num_powered_wheels, robot_wheel_radius, speed, accel, incline_grade
)
if rpm is not None:
    rpm = rpm.to("rpm").magnitude
table.append(
    ["Max speed on flat", rpm, torque.to("N m").magnitude, torque.to("kgf mm").magnitude, torque.to("kgf cm").magnitude]
)

#
# Accelerating on flat ground
#
speed = None
accel = 1.5 * units.meter / units.second**2
incline_grade = 0 * units.degrees

torque, rpm = calculate_motor_requirements(
    robot_mass, robot_num_powered_wheels, robot_wheel_radius, speed, accel, incline_grade
)
if rpm is not None:
    rpm = rpm.to("rpm").magnitude
table.append(
    ["Accel on flat", rpm, torque.to("N m").magnitude, torque.to("kgf mm").magnitude, torque.to("kgf cm").magnitude]
)

#
# Max speed on incline
#
speed = 1.0 * units.mps
accel = 0.0 * units.meter / units.second**2
incline_grade = 20 * units.degrees

torque, rpm = calculate_motor_requirements(
    robot_mass, robot_num_powered_wheels, robot_wheel_radius, speed, accel, incline_grade
)
if rpm is not None:
    rpm = rpm.to("rpm").magnitude
table.append(
    ["Max speed on incline", rpm, torque.to("N m").magnitude, torque.to("kgf mm").magnitude, torque.to("kgf cm").magnitude]
)

#
# Accelerating on incline
#
speed = None
accel = 0.5 * units.meter / units.second**2
incline_grade = 20 * units.degrees

torque, rpm = calculate_motor_requirements(
    robot_mass, robot_num_powered_wheels, robot_wheel_radius, speed, accel, incline_grade
)
if rpm is not None:
    rpm = rpm.to("rpm").magnitude
table.append(
    ["Accel on incline", rpm, torque.to("N m").magnitude, torque.to("kgf mm").magnitude, torque.to("kgf cm").magnitude]
)



print(tabulate(table, headers=headers, floatfmt=".2f"))
